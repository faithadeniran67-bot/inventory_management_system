# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Pandas Series

# %%
data = pd.Series([1.4, 3, 5, 6])

data
# Out:
# 0    1.4
# 1    3.0
# 2    5.0
# 3    6.0
# dtype: float64

# %%
type(data)
# Out:
# pandas.core.series.Series

# %%
data.index #index attribute
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
#explicit indexing

data_explicit = pd.Series([1.4, 3, 5, 6], index = ['a', 'b', 'c', 'd'])

data_explicit
# Out:
# a    1.4
# b    3.0
# c    5.0
# d    6.0
# dtype: float64

# %%
data_explicit.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
#values attribute

data.values
# Out:
# array([1.4, 3. , 5. , 6. ])
